# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/title.png' width=500/></center>

# %% [markdown]
# # 학습 목표
#
# - 시리즈와 데이터프레임 차이를 이해합니다.
# - 리스트와 딕셔너리에서 시리즈를 만들 수 있습니다.
# - 시리즈의 인덱스를 변경하거나 초기화할 수 있습니다.
# - 시리즈에 대한 기본 정보를 확인할 수 있습니다.
# - 시리즈를 대상으로 기본적인 조회와 연산을 할 수 있습니다.

# %% [markdown]
# # 0. 소개
#
# - Pandas는 파이썬 언어로 데이터 분석을 쉽게 할 수 있는 데이터 구조와 기능을 제공합니다.
# - Pandas 기능들을 사용하면 데이터 분석 과정 중 하나인 **데이터 전처리**를 쉽게 할 수 있습니다.
# - 머신러닝 또는 딥러닝 분야를 공부하려면 꼭 알아야 하는 **데이터 분석 필수 라이브러리**입니다.

# %% [markdown]
# ## 시리즈와 데이터프레임
#
# - **시리즈**는 **하나의 열**을 가지며, **데이터프레임**은 **하나 이상의 열**을 가짐이 가장 큰 차이입니다.
# - 아래 이미지처럼 **시리즈를 여러 개 합쳐진 것이 데이터프레임**이라고 할 수 있습니다.

# %% [markdown]
# <img src='https://raw.githubusercontent.com/Jangrae/img/master/series_dataframe.png' width=600 align="left"/>

# %% [markdown]
# # 1. 시리즈

# %% [markdown]
# - 시리즈는 데이터프레임과 더불어 Pandas가 제공하는 자료구조 중 하나입니다.
# - 시리즈는 **인덱스(Index)와 값(Value)으로 구성**됩니다.
# - 키(Key)와 값(values)으로 구성되는 딕셔너리와 형태가 유사합니다.
# - 데이터프레임에 대한 정보, 일부 데이터 또는 집계 결과가 시리즈 형태를 갖는 경우가 많습니다.

# %% [markdown]
# <img src='https://raw.githubusercontent.com/Jangrae/img/master/series.png' width=400 align="left"/>

# %% [markdown]
# - Pandas를 사용하려면 **pandas 라이브러리**를 불러와야 하며 일반적으로 **pd** 별칭을 사용합니다.

# %%
# 라이브러리 불러오기
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1.1. 시리즈 만들기
#
# - 다른 자료형을 **pd.Series()** 함수를 사용해 시리즈로 변환할 수 있습니다.
# - series()가 아니고 첫 글자가 대문자로 시작하는 <font color='red'>**S**</font>eries()임에 주의해야 합니다.

# %% [markdown]
# ### 1.1.1 인덱스 지정하지 않고 만들기

# %% [markdown]
# **1) 리스트로 만들기**
#
# - 인덱스를 지정하지 않으면 **0부터 시작하는 행 번호가 인덱스 값이 됩니다.**

# %%
# 리스트 만들기
list_stock = [92300, 94300, 92100, 92400, 92600]

# 시리즈 만들기
stock = pd.Series(list_stock)
stock
# Out:
# 0    92300
# 1    94300
# 2    92100
# 3    92400
# 4    92600
# dtype: int64

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# 아래 주어진 정보로 시리즈를 만들고 확인해 보세요.

# %%
# 리스트 만들기
score_list = [80, 75, 100, 90, 80]

# score2 시리즈 만들기
score2 = pd.Series(score_list)

# 시리즈 확인
score2
# Out:
# 0     80
# 1     75
# 2    100
# 3     90
# 4     80
# dtype: int64

# %%
score2[2]
# Out:
# 100

# %% [markdown]
# **2) 딕셔너리로 만들기**
#
# - 기본적으로 **딕셔너리의 키**가 **시리즈의 인덱스**로 사용됩니다.

# %% [markdown]
# <img src='https://raw.githubusercontent.com/Jangrae/img/master/dic_series.png' width=400 align="left"/>

# %%
# 딕셔너리 만들기
dict_stock = {'2019-02-15': 92300, 
              '2019-02-16': 94300, 
              '2019-02-17': 92100, 
              '2019-02-18': 92400, 
              '2019-02-19': 92600}
dict_stock
# Out:
# {'2019-02-15': 92300,
#  '2019-02-16': 94300,
#  '2019-02-17': 92100,
#  '2019-02-18': 92400,
#  '2019-02-19': 92600}

# %%
# 시리즈 만들기
stock = pd.Series(dict_stock)
stock
# Out:
# 2019-02-15    92300
# 2019-02-16    94300
# 2019-02-17    92100
# 2019-02-18    92400
# 2019-02-19    92600
# dtype: int64

# %%
stock['2019-02-17']
# Out:
# 92100

# %% [markdown]
# ### 1.1.2. 인덱스 지정해서 만들기
# - **index** 옵션에 인덱스로 사용할 데이터를 지정할 수 있습니다.
# - 날짜 데이터를 인덱스로 지정하는 경우가 많습니다.

# %%
# 리스트 만들기
list_stock = [92300, 94300, 92100, 92400, 92600]
dates = ['2019-02-15', '2019-02-16', '2019-02-17', '2019-02-18', '2019-02-19']

# 시리즈 만들기
stock = pd.Series(list_stock, index=dates)
stock
# Out:
# 2019-02-15    92300
# 2019-02-16    94300
# 2019-02-17    92100
# 2019-02-18    92400
# 2019-02-19    92600
# dtype: int64

# %%
# 리스트 만들기
list_stock = [92300, 94300, 92100, 92400, 92600]
idx = list('ABCDE')

# 시리즈 만들기
stock = pd.Series(list_stock, index=idx)
stock
# Out:
# A    92300
# B    94300
# C    92100
# D    92400
# E    92600
# dtype: int64

# %%
stock['F'] = 90000
stock
# Out:
# A    92300
# B    94300
# C    92100
# D    92400
# E    92600
# F    90000
# dtype: int64

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# 아래 주어진 리스트와 인덱스 정보를 사용해 시리즈를 만들고 확인해 보세요.

# %%
# 리스트 만들기
score_list = [80, 75, 100, 90, 80]
list_index = ['홍길동', '한사랑', '일지매', '박여인', '강우동']

# 시리즈 만들기
a = pd.Series(score_list, index=list_index)

# 시리즈 확인
a
# Out:
# 홍길동     80
# 한사랑     75
# 일지매    100
# 박여인     90
# 강우동     80
# dtype: int64

# %%
a.index
# Out:
# Index(['홍길동', '한사랑', '일지매', '박여인', '강우동'], dtype='object')

# %% [markdown]
# ### 1.1.3. 인덱스 변경과 초기화

# %% [markdown]
# **1) 인덱스 변경**
#
# - 이미 존재하는 시리즈의 인덱스는 **index** 속성을 변경해 바꿀 수 있습니다.

# %%
# 시리즈 만들기
stock = pd.Series([92300, 94300, 92100, 92400, 92600])
stock
# Out:
# 0    92300
# 1    94300
# 2    92100
# 3    92400
# 4    92600
# dtype: int64

# %% [markdown]
# - 인덱스 값을 날짜 데이터로 바꾸어봅니다.

# %%
# 인덱스 변경
dates = ['2019-02-15', '2019-02-16', '2019-02-17', '2019-02-18', '2019-02-19']
stock.index=dates
stock
# Out:
# 2019-02-15    92300
# 2019-02-16    94300
# 2019-02-17    92100
# 2019-02-18    92400
# 2019-02-19    92600
# dtype: int64

# %% [markdown]
# **2) 인덱스 초기화**
#
# - **reset_index()** 메소드를 사용해 인덱스를 행 번호에 기반한 정수 값으로 초기화 할 수 있습니다.
# - **drop=True** 옵션을 지정해 기존 인덱스를 버리게 해야 합니다.
# - **시리즈**는 값을 갖는 **열이 하나**이므로 기존 인덱스를 버리지 않으면 초기화 할 수 없습니다.
# - **데이터프레임**은 **여러 열**을 가지므로 기존 인덱스를 버리지 않고 일반 열로 남길 수 있습니다.

# %%
# 인덱스 초기화
stock = stock.reset_index(drop=True)
print(stock)
type(stock)
# Out:
# 0    92300
# 1    94300
# 2    92100
# 3    92400
# 4    92600
# dtype: int64
# pandas.core.series.Series

# %% [markdown]
# - reset_index() 메소드에는 **inplace** 옵션이 있습니다.
# - **inplace=True**를 지정하면 시리즈에 실제로 반영이 됩니다.

# %%
# 인덱스 초기화  ★★★★★ 인덱스를 초기화 하라면 inplace=True 꼭 적용한다!!!
stock.reset_index(drop=True, inplace=True)
print(stock)
# Out:
# 0    92300
# 1    94300
# 2    92100
# 3    92400
# 4    92600
# dtype: int64

# %% [markdown]
# ## 1.2. 인덱스, 값, 자료형, 크기 확인
#
# - 다음과 같은 속성으로 시리즈에 대한 정보를 확인합니다.
# - 이 방법은 이후 **데이터프레임에서 동일하게 적용**됩니다.
# - **index** 속성 → 인덱스 확인
# - **values** 속성 → 값 확인
# - **dtype** 속성 → 데이터 형식 확인
# - **shape** 속성 → 크기(=행 개수) 확인

# %%
# 딕셔너리 만들기
dict_stock = {'2019-02-15': 92300, 
              '2019-02-16': 94300, 
              '2019-02-17': 92100, 
              '2019-02-18': 92400, 
              '2019-02-19': 92600}
# 시리즈 만들기
stock = pd.Series(dict_stock)
stock
# Out:
# 2019-02-15    92300
# 2019-02-16    94300
# 2019-02-17    92100
# 2019-02-18    92400
# 2019-02-19    92600
# dtype: int64

# %%
# 인덱스 확인
stock.index
# Out:
# Index(['2019-02-15', '2019-02-16', '2019-02-17', '2019-02-18', '2019-02-19'], dtype='object')

# %%
# 값 확인
stock.values
# Out:
# array([92300, 94300, 92100, 92400, 92600])

# %%
# 자료형 확인
stock.dtype
# Out:
# dtype('int64')

# %%
# 크기 확인
stock.shape
# Out:
# (5,)

# %%
# 행 갯수 확인
stock.shape[0]
# Out:
# 5

# %% [markdown]
# ## 1.3. 인덱싱과 슬라이싱
#
# - 시리즈는 열이 하나이므로 인덱싱과 슬라이싱 방법이 단순합니다.

# %%
# 시리즈 만들기
dates = ['2019-02-15', '2019-02-16','2019-02-17','2019-02-18','2019-02-19']
stock = pd.Series([92300, 94300, 92100, 92400, 92600], index=dates)
stock
# Out:
# 2019-02-15    92300
# 2019-02-16    94300
# 2019-02-17    92100
# 2019-02-18    92400
# 2019-02-19    92600
# dtype: int64

# %%
stock.plot(kind='line', color='red', )

# %% [markdown]
# ### 1.3.1. 상위, 하위 n개 행 조회
#
# - 상위 n개의 행 조회할 때는 **head()** 메소드를 사용합니다.
# - 하위 n개의 행 조회할 때는 **tail()** 메소드를 사용합니다.
# - 괄호 안에 개수를 지정하시 않으면 5개 행이 기본적으로 조회됩니다.

# %%
# 상위 2개 행조회
stock.head(2)
# Out:
# 2019-02-15    92300
# 2019-02-16    94300
# dtype: int64

# %%
# 하위 2개 행 조회
stock.tail(2)
# Out:
# 2019-02-18    92400
# 2019-02-19    92600
# dtype: int64

# %%
# 상위 5개 행 조회
stock.head()
# Out:
# 2019-02-15    92300
# 2019-02-16    94300
# 2019-02-17    92100
# 2019-02-18    92400
# 2019-02-19    92600
# dtype: int64

# %%
stock.describe()
# Out:
# count        5.000000
# mean     92740.000000
# std        890.505474
# min      92100.000000
# 25%      92300.000000
# 50%      92400.000000
# 75%      92600.000000
# max      94300.000000
# dtype: float64

# %% [markdown]
# ### 1.3.2. 인덱싱
#
# - **행 번호** 또는 **인덱스 이름**을 사용해 조회할 수 있습니다.
# - 참고로 인덱스 이름, 인덱스 값, 인덱스 레이블 모두 같은 의미로 사용됩니다.

# %% [markdown]
# **1) 값 조회**
#
# - **[...]** 형태로 대괄호 한 겹을 사용해 조회하면 특정 값이 조회 됩니다.

# %%
# 첫째 행 값 조회
stock[0]
# Out:
# 92300

# %%
# 마지막 행 값 조회
stock[-1]
# Out:
# 92600

# %%
# '2019-02-15' 값 조회
stock['2019-02-15']
# Out:
# 92300

# %%
# '2019-02-19' 값 조회
stock['2019-02-19']
# Out:
# 92600

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# 아래 주어진 요구사항에 맞게 조회해 보세요.

# %%
# 셋째 행 값 조회
stock[2]
# Out:
# 92100

# %%
# '2019-02-18' 값 조회
stock['2019-02-18']
# Out:
# 92400

# %% [markdown]
# **2) 행 조회**
#
# - **[ [...] ]** 형태로 대괄호 두 겹을 사용하면 행이 조회됩니다.

# %%
# 시리즈 확인
stock
# Out:
# 2019-02-15    92300
# 2019-02-16    94300
# 2019-02-17    92100
# 2019-02-18    92400
# 2019-02-19    92600
# dtype: int64

# %%
# 첫째 행 조회
stock[[0]]
# Out:
# 2019-02-15    92300
# dtype: int64

# %%
# 첫쨰, 셋째 행 조회
stock[[0, 2]]
# Out:
# 2019-02-15    92300
# 2019-02-17    92100
# dtype: int64

# %%
# '2019-02-15' 행 조회
stock[['2019-02-15']]
# Out:
# 2019-02-15    92300
# dtype: int64

# %%
# '2019-02-15', '2019-02-19' 행 조회
stock[['2019-02-15', '2019-02-19']]
# Out:
# 2019-02-15    92300
# 2019-02-19    92600
# dtype: int64

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# 아래 주어진 요구사항에 맞게 조회해 보세요.

# %%
# 마지막 행 조회
stock[[-1]]
# Out:
# 2019-02-19    92600
# dtype: int64

# %%
# 첫째 행, 마지막 행 조회

# %%
# '2019-02-15', '2019-02-17', '2019-02-19' 행 조회

# %% [markdown]
# ### 1.3.3. 슬라이싱
#
# - 범위를 지정해 슬라이싱 할 수 있습니다.

# %%
# 시리즈 확인
stock
# Out:
# 2019-02-15    92300
# 2019-02-16    94300
# 2019-02-17    92100
# 2019-02-18    92400
# 2019-02-19    92600
# dtype: int64

# %%
# 첫째 행 ~ 셋째 행  조회
stock[0:3]
# Out:
# 2019-02-15    92300
# 2019-02-16    94300
# 2019-02-17    92100
# dtype: int64

# %%
# 2018-02-15 ~ 2018-02-17 행 조회
stock['2019-02-15':'2019-02-17']
# Out:
# 2019-02-15    92300
# 2019-02-16    94300
# 2019-02-17    92100
# dtype: int64

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# 아래 주어진 요구사항에 맞게 조회해 보세요.

# %%
# 맨 뒤 세 개 행 조회
stock[-3:]
# Out:
# 2019-02-17    92100
# 2019-02-18    92400
# 2019-02-19    92600
# dtype: int64

# %%
# 첫째 행부터 두 개 행
stock[0:2]
# Out:
# 2019-02-15    92300
# 2019-02-16    94300
# dtype: int64

# %%
# '2019-02-16' ~ '2019-02-19' 행 조회
stock['2019-02-16' : '2019-02-19']
# Out:
# 2019-02-16    94300
# 2019-02-17    92100
# 2019-02-18    92400
# 2019-02-19    92600
# dtype: int64

# %% [markdown]
# ## 1.4. 시리즈 연산
#
# - 시리즈 간의 인덱스 위치가 달라도, 인덱스 값을 기준으로 연산이 됩니다.
# - 매치되는 인덱스를 찾지 못하면 값이 결과 값은 NaN이 됩니다.

# %%
# 시리즈 만들기
score_math1 = pd.Series([80, 85, 85, 75], index = ['홍길동', '한사랑', '일지매', '박여인'])
score_math1
# Out:
# 홍길동    80
# 한사랑    85
# 일지매    85
# 박여인    75
# dtype: int64

# %% [markdown]
# **1) 숫자와의 연산**
#
# - 시리즈가 갖는 값에 특정 값을 더하거나 빼는 등의 연산이 가능합니다.
# - 단순히 더하고 빼주면 됩니다.

# %%
# 시리즈에 10 더라기
score_math1 + 10
# Out:
# 홍길동    90
# 한사랑    95
# 일지매    95
# 박여인    85
# dtype: int64

# %%
# 100에서 시리즈 빼기
100 - score_math1
# Out:
# 홍길동    20
# 한사랑    15
# 일지매    15
# 박여인    25
# dtype: int64

# %% [markdown]
# **2) 시리즈  사이의 연산**
#
# - 시리즈 간의 연산도 단순히 더하거나 빼주면 됩니다.

# %%
# 시리즈 만들기
score_math1 = pd.Series([80, 85, 85, 75], index = ['홍길동', '한사랑', '일지매', '박여인'])
score_math1
# Out:
# 홍길동    80
# 한사랑    85
# 일지매    85
# 박여인    75
# dtype: int64

# %%
# 시리즈 만들기
score_math2 = pd.Series([85, 90, 95], index = ['홍길동', '일지매', '한사랑'])
score_math2
# Out:
# 홍길동    85
# 일지매    90
# 한사랑    95
# dtype: int64

# %%
# 시리즈 더하기, NaN = null = 결측치,
# NaN 값이 있는 경우 데이터 타입이 float이 된다
score_math1 + score_math2
# Out:
# 박여인      NaN
# 일지매    175.0
# 한사랑    180.0
# 홍길동    165.0
# dtype: float64

# %%
# 시리즈 빼기
score_math2 - score_math1
# Out:
# 박여인     NaN
# 일지매     5.0
# 한사랑    10.0
# 홍길동     5.0
# dtype: float64

# %%
a = np.nan
a
# Out:
# nan

# %%
a = None
a

# %% [markdown]
# ## <center>수고하셨습니다.</center>
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/end.png' width=200/></center>
