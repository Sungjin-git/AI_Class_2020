# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/title.png' width=500/></center>

# %% [markdown]
# # 학습 목표
#
# - 리스트와 딕셔너리에서 데이터프레임을 만들 수 있습니다.
# - 파일에서 읽어와 데이터프레임을 만들 수 있습니다.
# - 임의의 값을 갖는 데이터프레임을 만들 수 있습니다.
# - 데이터프레임의 인덱스를 변경하거나 초기화 할 수 있습니다.

# %% [markdown]
# # 2. 데이터프레임 만들기
#
# - 데이터프레임은 시리즈와는 달리 **하나 이상의 열**을 갖는 형태입니다.
# - 일반적으로 접하게 되는 **테이블** 형태, **엑셀** 형태로 생각하시면 됩니다.

# %% [markdown]
# <img src='https://raw.githubusercontent.com/Jangrae/img/master/dataframe.png' width=750 align="left"/>

# %% [markdown]
# - 직접 만들 수 있으나 보통은 파일(csv 또는 엑셀 파일 등) 또는 DB에서 읽어옵니다.
# - 데이터프레임을 만들 때 인덱스를 지정하는 부분은 시리즈와 같은 개념입니다.

# %%
# 라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2.1. 데이터프레임 만들기
#
# - **pd.DataFrame()** 함수를 사용해 데이터프레임을 만듭니다.
# - 데이터프레임을 만들 때 **열 이름**을 직접 지정할 수 있습니다.
# - 열 이름을 지정하지 않으면 **열 번호**에 기반한 정수(0, 1, 2...)가 열 이름이 됩니다.

# %% [markdown]
# ### 2.1.1. 딕셔너리로 만들기
#
# - 딕셔너리로 데이터프레임을 만들면 딕셔너리의 **키**가 **열 이름**이 됩니다.
# - 인덱스를 지정하지 않으면 행 번호가 인덱스 값이 됩니다.

# %%
# 딕셔너리 만들기
dict = {'이름': ['홍길동', '한사랑', '일지매', '박여인'],
        '등급': ['Gold', 'Bronze', 'Silver', 'Gold'],
        '점수': [56000, 23000, 44000, 52000]}
dict
# Out:
# {'등급': ['Gold', 'Bronze', 'Silver', 'Gold'],
#  '이름': ['홍길동', '한사랑', '일지매', '박여인'],
#  '점수': [56000, 23000, 44000, 52000]}

# %%
# 데이터프레임 만들기
df = pd.DataFrame(dict)
df.head()
# Out:
#     이름      등급     점수
# 0  홍길동    Gold  56000
# 1  한사랑  Bronze  23000
# 2  일지매  Silver  44000
# 3  박여인    Gold  52000

# %% [markdown]
# - 필요하면 인덱스를 별도로 지정할 수 있습니다.

# %%
# 딕셔너리 만들기
dict = {
   '이름': ['홍길동', '한사랑', '일지매', '박여인'],
   '등급': ['Gold', 'Bronze', 'Silver', 'Gold'],
   '점수': [56000, 23000, 44000, 52000]
}

# 데이터프레임 만들기(인덱스 지정함)
df = pd.DataFrame(dict, index=['C0001', 'C0002', 'C0003', 'C0004'])
df.head()
# Out:
#         이름      등급     점수
# C0001  홍길동    Gold  56000
# C0002  한사랑  Bronze  23000
# C0003  일지매  Silver  44000
# C0004  박여인    Gold  52000

# %% [markdown]
# ### 2.1.2. 리스트로  만들기
#
# - 인덱스를 지정하지 않으면 행 번호가 인덱스 값, 열 번호가 열 이름이 됩니다.

# %%
# 리스트 만들기
stock = [[94500, 92100, 92200, 92300],
         [96500, 93200, 95900, 94300],
         [93400, 91900, 93400, 92100],
         [94200, 92100, 94100, 92400],
         [94500, 92500, 94300, 92600]]

# 데이터프레임 만들기
df = pd.DataFrame(stock)
df.head()
# Out:
#        0      1      2      3
# 0  94500  92100  92200  92300
# 1  96500  93200  95900  94300
# 2  93400  91900  93400  92100
# 3  94200  92100  94100  92400
# 4  94500  92500  94300  92600

# %% [markdown]
# - 필요하면 인덱스와 열 이름을 별도로 지정할 수 있습니다.

# %%
df.plot(kind='box', title='Stock Info')
plt.show()

# %%
# 리스트 만들기
stock = [[94500, 92100, 92200, 92300],
         [96500, 93200, 95900, 94300],
         [93400, 91900, 93400, 92100],
         [94200, 92100, 94100, 92400],
         [94500, 92500, 94300, 92600]]
dates = ['2019-02-15', '2019-02-16', '2019-02-17', '2019-02-18', '2019-02-19']
names = ['High', 'Low', 'Open', 'Close']

# 데이터프레임 만들기
df = pd.DataFrame(stock, index=dates, columns=names)
df.head()
# Out:
#              High    Low   Open  Close
# 2019-02-15  94500  92100  92200  92300
# 2019-02-16  96500  93200  95900  94300
# 2019-02-17  93400  91900  93400  92100
# 2019-02-18  94200  92100  94100  92400
# 2019-02-19  94500  92500  94300  92600

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# 아래 주어진 리스트와 인덱스 정보를 사용해 데이터프레임 score를 만들고 확인해 보세요.

# %%
# 리스트 만들기
score_list = [80, 75, 100, 90, 80]
list_index = ['홍길동', '한사랑', '일지매', '박여인', '강우동']
list_columns = ['점수']

# 데이터프레임 만들기
df = pd.DataFrame(score_list, index=list_index, columns=list_columns)

# 확인
df.head()
# Out:
#       점수
# 홍길동   80
# 한사랑   75
# 일지매  100
# 박여인   90
# 강우동   80

# %% [markdown]
# ## 2.2. CSV파일 읽어오기

# %% [markdown]
# - 분석용 데이터는 대부분 파일에서 읽어 가져옵니다.
# - **read_csv()** 함수를 사용해서 CSV 파일에서 데이터를 읽어옵니다.
#
# **[중요옵션]**
# - sep: 구분자 지정(기본값 = 콤마)
# - header: 헤더가 될 행 번호 지정(기본값 = 0)
# - index_col: 인덱스 열 지정(기본값 = False)
# - names: 열 이름으로 사용할 문자열 리스트
# - skiprows: 처음 몇 줄을 무시할 것인지 지정, 리스트로 지정 가능

# %%
# Titanic 데이터 불러오기
file_path = 'https://raw.githubusercontent.com/Jangrae/csv/master/titanic_simple.csv'
titanic = pd.read_csv(file_path, sep = ',', header=0, index_col=False)  
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  ...   Age     Fare      Embarked
# 0            1         0       3  ...  22.0   7.2500  Southhampton
# 1            2         1       1  ...  38.0  71.2833     Cherbourg
# 2            3         1       3  ...  26.0   7.9250  Southhampton
# 3            4         1       1  ...  35.0  53.1000  Southhampton
# 4            5         0       3  ...  35.0   8.0500  Southhampton
# 5            6         0       3  ...   NaN   8.4583    Queenstown
# 6            7         0       1  ...  54.0  51.8625  Southhampton
# 7            8         0       3  ...   2.0  21.0750  Southhampton
# 8            9         1       3  ...  27.0  11.1333  Southhampton
# 9           10         1       2  ...  14.0  30.0708     Cherbourg
#
# [10 rows x 8 columns]

# %%
# 인덱스 열 지정, 몇몇 행 무시하고 불러오기
file_path = 'https://raw.githubusercontent.com/Jangrae/csv/master/titanic_simple.csv'
titanic = pd.read_csv(file_path, sep = ',', index_col='PassengerId', skiprows=[1, 3, 5])  
titanic.head(10)
# Out:
#              Survived  Pclass  ...     Fare      Embarked
# PassengerId                    ...
# 2                   1       1  ...  71.2833     Cherbourg
# 4                   1       1  ...  53.1000  Southhampton
# 6                   0       3  ...   8.4583    Queenstown
# 7                   0       1  ...  51.8625  Southhampton
# 8                   0       3  ...  21.0750  Southhampton
# 9                   1       3  ...  11.1333  Southhampton
# 10                  1       2  ...  30.0708     Cherbourg
# 11                  1       3  ...  16.7000  Southhampton
# 12                  1       1  ...  26.5500  Southhampton
# 13                  0       3  ...   8.0500  Southhampton
#
# [10 rows x 7 columns]

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# 아래 주어진 경로의 파일에서 데이터를 읽어와 데이터프레임 graduate 만들어 보세요.
#
# - 파일 경로: 'https://raw.githubusercontent.com/Jangrae/csv/master/Graduate_apply.csv'

# %%
# 파일에서 데이터 읽어와 데이터프레임 만들기
graduate = pd.read_csv('https://raw.githubusercontent.com/Jangrae/csv/master/Graduate_apply.csv')

# 확인
graduate.head()
# Out:
#    admit  gre   gpa  rank
# 0      0  380  3.61     3
# 1      1  660  3.67     3
# 2      1  800  4.00     1
# 3      1  640  3.19     4
# 4      0  520  2.93     4

# %%
graduate.describe()
# Out:
#             admit         gre         gpa       rank
# count  400.000000  400.000000  400.000000  400.00000
# mean     0.317500  587.700000    3.389900    2.48500
# std      0.466087  115.516536    0.380567    0.94446
# min      0.000000  220.000000    2.260000    1.00000
# 25%      0.000000  520.000000    3.130000    2.00000
# 50%      0.000000  580.000000    3.395000    2.00000
# 75%      1.000000  660.000000    3.670000    3.00000
# max      1.000000  800.000000    4.000000    4.00000

# %%
graduate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   admit   400 non-null    int64
#  1   gre     400 non-null    int64
#  2   gpa     400 non-null    float64
#  3   rank    400 non-null    int64
# dtypes: float64(1), int64(3)
# memory usage: 12.6 KB

# %% [markdown]
# ## 2.3. 임의의 값을 갖는 데이터프레임 만들기
#
# - 테스트용 데이터프레임을 만들 때 많이 사용하니 익혀두는 것이 좋습니다.

# %% [markdown]
# **[참고] 난수 발생 방법**
#
# - random.**rand()**: 0부터 1사이의 균일 분포 임의 실수
# - random.**randn()**: 가우시안 표준 정규 분포 임의 실수
# - random.**randint()**: 균일 분포의 임의 정수

# %% [markdown]
# **1) 임의의 실수값**
#
# - 일정 기간의 날짜 데이터를 만들어 내는 **date_range()** 함수도 기억하기 바랍니다.

# %%
# 2020-02-01 부터 날짜 10개 만들기
dates = pd.date_range('20200201', periods=1000)

# 임의의 실수를 갖는 10 x 4 형태의 2차원 배열 만들기
nums = np.random.randn(1000, 4)

# 데이터프레임 만들기
df = pd.DataFrame(nums, index=dates, columns=list('ABCD'))
df.head(10)
# Out:
#                    A         B         C         D
# 2020-02-01  0.841798  0.417211 -1.004389 -0.830446
# 2020-02-02 -1.738324  2.001123  1.018969  1.437279
# 2020-02-03 -0.916796  0.646644 -0.161533  1.217715
# 2020-02-04  0.194265 -1.382660  1.494839  1.308600
# 2020-02-05  0.008145  0.998341 -0.528198  0.458526
# 2020-02-06 -0.392600  0.763377 -0.410824  0.977905
# 2020-02-07 -1.249483 -0.318735  1.323855  0.716871
# 2020-02-08  0.327560 -1.125645 -0.852335  0.771355
# 2020-02-09 -0.015229 -1.206303  0.059466  0.440978
# 2020-02-10 -1.300904 -1.507478  0.783092  1.335548

# %%
df.plot(kind='hist', y=['A', 'B'], figsize=(10, 10), )
plt.show()

# %% [markdown]
# **2) 임의의 정수값**

# %%
# 2020-02-01 부터 10개이 날짜 만들기
dates = pd.date_range('20200201', periods=10)

# 지정한 범위 내의 임의의 정수를 갖는 10 x 4 형태의 2차원 배열 만들기
nums = np.random.randint(100000, 200000, size=(10, 4))

# 데이터프레임 만들기
df = pd.DataFrame(nums, index=dates, columns=list(['col1', 'col2', 'col3', 'col4']))
df.head(10)
# Out:
#               col1    col2    col3    col4
# 2020-02-01  156499  191311  136985  170400
# 2020-02-02  178780  166067  141607  111952
# 2020-02-03  187064  193412  101104  192863
# 2020-02-04  119985  191239  142475  150325
# 2020-02-05  126729  121427  184198  182786
# 2020-02-06  170886  187269  141143  122616
# 2020-02-07  137974  154429  151542  115011
# 2020-02-08  146424  114490  156851  199543
# 2020-02-09  122372  138550  142213  136704
# 2020-02-10  190530  116223  130691  150201

# %% [markdown]
# ## 2.4. 인덱스 다시 설정
#
# - 일반 열을 인덱스 열로 설정하거나, 위치 인덱스로 초기화 할 수 있습니다.

# %%
# stock 데이터 불러오기
file_path = 'https://raw.githubusercontent.com/jangrae/csv/master/stock.csv'
stock = pd.read_csv(file_path, sep = ',', skipinitialspace = True)  
stock.head(10)
# Out:
#          Date      High       Low      Open     Close     Volume  Adj Close
# 0  2000-01-03  4.017857  3.631696  3.745536  3.997768  133949200   3.470226
# 1  2000-01-04  3.950893  3.613839  3.866071  3.660714  128094400   3.177650
# 2  2000-01-05  3.948661  3.678571  3.705357  3.714286  194580400   3.224152
# 3  2000-01-06  3.821429  3.392857  3.790179  3.392857  191993200   2.945139
# 4  2000-01-07  3.607143  3.410714  3.446429  3.553571  115183600   3.084645
# 5  2000-01-10  3.651786  3.383929  3.642857  3.491071  126266000   3.030393
# 6  2000-01-11  3.549107  3.232143  3.426339  3.312500  110387200   2.875386
# 7  2000-01-12  3.410714  3.089286  3.392857  3.113839  244017200   2.702940
# 8  2000-01-13  3.526786  3.303571  3.374442  3.455357  258171200   2.999391
# 9  2000-01-14  3.651786  3.549107  3.571429  3.587054   97594000   3.113708

# %%
stock.tail(10)
# Out:
#             Date        High         Low  ...       Close    Volume   Adj Close
# 5021  2019-12-17  281.769989  278.799988  ...  280.410004  28539600  279.746094
# 5022  2019-12-18  281.899994  279.119995  ...  279.739990  29007100  279.077667
# 5023  2019-12-19  281.179993  278.950012  ...  280.019989  24592300  279.356995
# 5024  2019-12-20  282.649994  278.559998  ...  279.440002  68994500  278.778381
# 5025  2019-12-23  284.250000  280.369995  ...  284.000000  24643000  283.327576
# 5026  2019-12-24  284.890015  282.920013  ...  284.269989  12119700  283.596924
# 5027  2019-12-26  289.980011  284.700012  ...  289.910004  23280300  289.223602
# 5028  2019-12-27  293.970001  288.119995  ...  289.799988  36566500  289.113831
# 5029  2019-12-30  292.690002  285.220001  ...  291.519989  36028600  290.829773
# 5030  2019-12-31  293.679993  289.519989  ...  293.649994  25201400  292.954712
#
# [10 rows x 7 columns]

# %% [markdown]
# **1) 일반 열을 인덱스로 지정**
#
# - 파일을 불러올 때 **index_col** 옵션을 사용해 인덱스 열을 선택할 수 있습니다.
# - 파일을 불러온 후에 **set_index()** 메소드를 사용해 인덱스 열을 설정할 수 있습니다.

# %%
# ★★★ 기존 열 중에서 인덱스열 선택
stock.set_index('Date', inplace=True)
stock.head()
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# Date
# 2000-01-03  4.017857  3.631696  3.745536  3.997768  133949200   3.470226
# 2000-01-04  3.950893  3.613839  3.866071  3.660714  128094400   3.177650
# 2000-01-05  3.948661  3.678571  3.705357  3.714286  194580400   3.224152
# 2000-01-06  3.821429  3.392857  3.790179  3.392857  191993200   2.945139
# 2000-01-07  3.607143  3.410714  3.446429  3.553571  115183600   3.084645

# %% [markdown]
# **2) 인덱스 이름 삭제**

# %%
# ★★★ 
stock.index.name = None
stock.head()
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# 2000-01-03  4.017857  3.631696  3.745536  3.997768  133949200   3.470226
# 2000-01-04  3.950893  3.613839  3.866071  3.660714  128094400   3.177650
# 2000-01-05  3.948661  3.678571  3.705357  3.714286  194580400   3.224152
# 2000-01-06  3.821429  3.392857  3.790179  3.392857  191993200   2.945139
# 2000-01-07  3.607143  3.410714  3.446429  3.553571  115183600   3.084645

# %% [markdown]
# **3) 인덱스 초기화**
#
# - **reset_index()** 메소드를 사용해 행 번호에 기반한 정수 값으로 인덱스를 초기화 할 수 있습니다.
# - **drop=True**를 설정하면 기존 인덱스열을 일반 열로 가져오지 않고 버립니다.(기본값=False)

# %%
# ★★★ 인덱스열을 일반열로 바꾸고 기본 인덱스(0, 1, 2,..) 열 추가
stock.reset_index(drop=False, inplace=True)
stock.head()
# Out:
#         index      High       Low      Open     Close     Volume  Adj Close
# 0  2000-01-03  4.017857  3.631696  3.745536  3.997768  133949200   3.470226
# 1  2000-01-04  3.950893  3.613839  3.866071  3.660714  128094400   3.177650
# 2  2000-01-05  3.948661  3.678571  3.705357  3.714286  194580400   3.224152
# 3  2000-01-06  3.821429  3.392857  3.790179  3.392857  191993200   2.945139
# 4  2000-01-07  3.607143  3.410714  3.446429  3.553571  115183600   3.084645

# %% [markdown]
# - 열 이름 변경

# %%
# ★★★ 
stock.rename(columns={'index': 'Date'}, inplace=True)
stock.head()
# Out:
#          Date      High       Low      Open     Close     Volume  Adj Close
# 0  2000-01-03  4.017857  3.631696  3.745536  3.997768  133949200   3.470226
# 1  2000-01-04  3.950893  3.613839  3.866071  3.660714  128094400   3.177650
# 2  2000-01-05  3.948661  3.678571  3.705357  3.714286  194580400   3.224152
# 3  2000-01-06  3.821429  3.392857  3.790179  3.392857  191993200   2.945139
# 4  2000-01-07  3.607143  3.410714  3.446429  3.553571  115183600   3.084645

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# 아래 주어진 데이터프레임을 확인하고, 이어지는 셀에 코드를 완성해 보세요.

# %%
# 데이터프레임 만들기
dates = pd.date_range('20200201', periods=10)
nums = np.random.randn(10, 4)
df = pd.DataFrame(nums, index=dates, columns=list('ABCD'))
df.head()
# Out:
#                    A         B         C         D
# 2020-02-01  1.411126  1.392591  1.057811 -0.033825
# 2020-02-02 -0.140140  0.365225 -1.695544 -0.574455
# 2020-02-03 -1.564859 -0.487707  1.236239  1.791505
# 2020-02-04 -0.448513  0.677665  0.123893 -0.210387
# 2020-02-05  0.316281  0.039352  0.798000  1.819812

# %%
# 인덱스를 정수형 위치 인덱스로 초기화
df.reset_index(drop=False, inplace=True)

# 확인
df.head()
# Out:
#        index         A         B         C         D
# 0 2020-02-01  1.411126  1.392591  1.057811 -0.033825
# 1 2020-02-02 -0.140140  0.365225 -1.695544 -0.574455
# 2 2020-02-03 -1.564859 -0.487707  1.236239  1.791505
# 3 2020-02-04 -0.448513  0.677665  0.123893 -0.210387
# 4 2020-02-05  0.316281  0.039352  0.798000  1.819812

# %%
# 날짜 열 이름을 Date로 변경
df.rename(columns={'index': 'Date'}, inplace=True)

# 확인
df.head()
# Out:
#         Date         A         B         C         D
# 0 2020-02-01  1.411126  1.392591  1.057811 -0.033825
# 1 2020-02-02 -0.140140  0.365225 -1.695544 -0.574455
# 2 2020-02-03 -1.564859 -0.487707  1.236239  1.791505
# 3 2020-02-04 -0.448513  0.677665  0.123893 -0.210387
# 4 2020-02-05  0.316281  0.039352  0.798000  1.819812

# %%
# 인덱스를 날짜 데이터가 있는 열로 다시 변경
df.set_index('Date', inplace=True)

# 확인
df.head()
# Out:
#                    A         B         C         D
# Date
# 2020-02-01  1.411126  1.392591  1.057811 -0.033825
# 2020-02-02 -0.140140  0.365225 -1.695544 -0.574455
# 2020-02-03 -1.564859 -0.487707  1.236239  1.791505
# 2020-02-04 -0.448513  0.677665  0.123893 -0.210387
# 2020-02-05  0.316281  0.039352  0.798000  1.819812

# %%
# 인덱스 이름 삭제
df.index.name = None

# 확인
df.head()
# Out:
#                    A         B         C         D
# 2020-02-01  1.411126  1.392591  1.057811 -0.033825
# 2020-02-02 -0.140140  0.365225 -1.695544 -0.574455
# 2020-02-03 -1.564859 -0.487707  1.236239  1.791505
# 2020-02-04 -0.448513  0.677665  0.123893 -0.210387
# 2020-02-05  0.316281  0.039352  0.798000  1.819812

# %% [markdown]
# ## <center>수고하셨습니다</center>
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/end.png' width=200/></center>
