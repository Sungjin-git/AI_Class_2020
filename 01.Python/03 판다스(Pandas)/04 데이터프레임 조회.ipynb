# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/title.png' width=500/></center>

# %% [markdown]
# # 학습 목표
#
# - 특정 값, 특정 행, 특정 열의 데이터를 조회할 수 있습니다.
# - 특정 조건을 만족하는 데이터를 조회할 수 있습니다.

# %% [markdown]
# # 4. 데이터프레임 조회
#
# - 보고자 하는 데이터를 즉시 조회할 수 있도록 반복 학습과 실습을 통해 익숙해져야 합니다.
# - 데이터프레임을 대상으로 조회하는 방법은 다양합니다.
# - 각자가 편하다 느끼는 방법을 선택해 그것을 쓰면 됩니다.

# %%
# 라이브러리 불러오기
import pandas as pd
import numpy as np

# %% [markdown]
# ## 4.1. 데이터 불러오기

# %%
# Titanic 데이터 불러오기
file_path = 'https://raw.githubusercontent.com/Jangrae/csv/master/titanic_simple.csv'
titanic = pd.read_csv(file_path, sep = ',', skipinitialspace = True)  
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  ...   Age     Fare      Embarked
# 0            1         0       3  ...  22.0   7.2500  Southhampton
# 1            2         1       1  ...  38.0  71.2833     Cherbourg
# 2            3         1       3  ...  26.0   7.9250  Southhampton
# 3            4         1       1  ...  35.0  53.1000  Southhampton
# 4            5         0       3  ...  35.0   8.0500  Southhampton
#
# [5 rows x 8 columns]

# %%
# Stock 데이터 불러오기
file_path = 'https://raw.githubusercontent.com/Jangrae/csv/master/stock.csv'
stock = pd.read_csv(file_path, sep = ',', skipinitialspace = True)  

# Date 열을 인덱스 열로 지정
stock.set_index(['Date'], inplace = True)
stock.index.name = None
stock.head()
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# 2000-01-03  4.017857  3.631696  3.745536  3.997768  133949200   3.470226
# 2000-01-04  3.950893  3.613839  3.866071  3.660714  128094400   3.177650
# 2000-01-05  3.948661  3.678571  3.705357  3.714286  194580400   3.224152
# 2000-01-06  3.821429  3.392857  3.790179  3.392857  191993200   2.945139
# 2000-01-07  3.607143  3.410714  3.446429  3.553571  115183600   3.084645

# %%
stock.head(2)
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# 2000-01-03  4.017857  3.631696  3.745536  3.997768  133949200   3.470226
# 2000-01-04  3.950893  3.613839  3.866071  3.660714  128094400   3.177650

# %%
# 인덱스 초기화 & 열 이름 변경
stock.reset_index(drop=False, inplace=True)
stock.rename(columns={'index' : 'Date'}, inplace=True)
stock.head()
# Out:
#          Date      High       Low      Open     Close     Volume  Adj Close
# 0  2000-01-03  4.017857  3.631696  3.745536  3.997768  133949200   3.470226
# 1  2000-01-04  3.950893  3.613839  3.866071  3.660714  128094400   3.177650
# 2  2000-01-05  3.948661  3.678571  3.705357  3.714286  194580400   3.224152
# 3  2000-01-06  3.821429  3.392857  3.790179  3.392857  191993200   2.945139
# 4  2000-01-07  3.607143  3.410714  3.446429  3.553571  115183600   3.084645

# %%
# Date 열을 인덱스 설정 & 인덱스 이름 삭제
stock.set_index('Date', inplace=True)
stock.index.name = None
stock.head()
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# 2000-01-03  4.017857  3.631696  3.745536  3.997768  133949200   3.470226
# 2000-01-04  3.950893  3.613839  3.866071  3.660714  128094400   3.177650
# 2000-01-05  3.948661  3.678571  3.705357  3.714286  194580400   3.224152
# 2000-01-06  3.821429  3.392857  3.790179  3.392857  191993200   2.945139
# 2000-01-07  3.607143  3.410714  3.446429  3.553571  115183600   3.084645

# %% [markdown]
# ## 4.2. 이름으로 조회
#
# - **.loc[[행이름], [열이름]]**을 사용해 조회할 수 있습니다.

# %%
# 데이터프레임 확인
stock.head()
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# 2000-01-03  4.017857  3.631696  3.745536  3.997768  133949200   3.470226
# 2000-01-04  3.950893  3.613839  3.866071  3.660714  128094400   3.177650
# 2000-01-05  3.948661  3.678571  3.705357  3.714286  194580400   3.224152
# 2000-01-06  3.821429  3.392857  3.790179  3.392857  191993200   2.945139
# 2000-01-07  3.607143  3.410714  3.446429  3.553571  115183600   3.084645

# %% [markdown]
# **1) 열 조회**
#
# - **df.loc[:,['열이름']]** 형태로 조회하면 특정 열을 조회합니다.
# - 행 부분을 생략할 수는 없습니다.

# %%
# Close 열 조회
stock.loc[:,['Close']].head()
# Out:
#                Close
# 2000-01-03  3.997768
# 2000-01-04  3.660714
# 2000-01-05  3.714286
# 2000-01-06  3.392857
# 2000-01-07  3.553571

# %%
# Open 열 조회 --> 데이터프레임
stock.loc[:, ['Open']].head()
# Out:
#                 Open
# 2000-01-03  3.745536
# 2000-01-04  3.866071
# 2000-01-05  3.705357
# 2000-01-06  3.790179
# 2000-01-07  3.446429

# %%
# Open 열 조회 --> 시리즈
stock.loc[:, 'Open'].head()
# Out:
# 2000-01-03    3.745536
# 2000-01-04    3.866071
# 2000-01-05    3.705357
# 2000-01-06    3.790179
# 2000-01-07    3.446429
# Name: Open, dtype: float64

# %% [markdown]
# - **df[['열이름']]** 형태로도 많이 사용합니다.
# - 열 하나를 지정할 때는 **df['열이름']** 형태로 사용합니다.

# %%
# Close 열 조회
stock['Close'].head()
# Out:
# 2000-01-03    3.997768
# 2000-01-04    3.660714
# 2000-01-05    3.714286
# 2000-01-06    3.392857
# 2000-01-07    3.553571
# Name: Close, dtype: float64

# %%
# Close 열 조회 --> 데이터프레임
stock[['Close']].head()
# Out:
#                Close
# 2000-01-03  3.997768
# 2000-01-04  3.660714
# 2000-01-05  3.714286
# 2000-01-06  3.392857
# 2000-01-07  3.553571

# %%
# 참고 : 난 안쓸래!
stock.Close.head()
# Out:
# 2000-01-03    3.997768
# 2000-01-04    3.660714
# 2000-01-05    3.714286
# 2000-01-06    3.392857
# 2000-01-07    3.553571
# Name: Close, dtype: float64

# %% [markdown]
# - 열 이름을 여럿 나열하여 여러 열을 조회할 수 있습니다.

# %%
# Open, Close, Volume 열 조회
stock[['Open', 'Close', 'Volume']].head()
# Out:
#                 Open     Close     Volume
# 2000-01-03  3.745536  3.997768  133949200
# 2000-01-04  3.866071  3.660714  128094400
# 2000-01-05  3.705357  3.714286  194580400
# 2000-01-06  3.790179  3.392857  191993200
# 2000-01-07  3.446429  3.553571  115183600

# %%
# Open, Close, Volume 열 조회 : loc 사용
stock.loc[:,['Open', 'Close', 'Volume']].head()
# Out:
#                 Open     Close     Volume
# 2000-01-03  3.745536  3.997768  133949200
# 2000-01-04  3.866071  3.660714  128094400
# 2000-01-05  3.705357  3.714286  194580400
# 2000-01-06  3.790179  3.392857  191993200
# 2000-01-07  3.446429  3.553571  115183600

# %%
# Open, Close, Volume 열 조회
stock[['Open', 'Close']].tail(100).plot()

# %% [markdown]
# - 범위를 지정해 조회할 수 있습니다.
# - 범위 조회는 **df.loc[:,['열이름']]** 형태를 지켜야 합니다.
# - 또한 **대괄호를 사용하면 안됩니다.**

# %%
# High, Low, Close, Volume 열 조회 
# ★ 이름으로 검색할 때는 마지막 값도 포함
# 컬럼 범위 검색할 때는 꼭 loc를 사용해야 함
stock.loc[:, 'High':'Close'].head()
# Out:
#                 High       Low      Open     Close
# 2000-01-03  4.017857  3.631696  3.745536  3.997768
# 2000-01-04  3.950893  3.613839  3.866071  3.660714
# 2000-01-05  3.948661  3.678571  3.705357  3.714286
# 2000-01-06  3.821429  3.392857  3.790179  3.392857
# 2000-01-07  3.607143  3.410714  3.446429  3.553571

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# titanic 데이터프레임에 대해 열을 조회하는 아래 셀 내용욜 작성해 보세요.

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  ...   Age     Fare      Embarked
# 0            1         0       3  ...  22.0   7.2500  Southhampton
# 1            2         1       1  ...  38.0  71.2833     Cherbourg
# 2            3         1       3  ...  26.0   7.9250  Southhampton
# 3            4         1       1  ...  35.0  53.1000  Southhampton
# 4            5         0       3  ...  35.0   8.0500  Southhampton
#
# [5 rows x 8 columns]

# %%
# 상위 5개 행 조회
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  ...   Age     Fare      Embarked
# 0            1         0       3  ...  22.0   7.2500  Southhampton
# 1            2         1       1  ...  38.0  71.2833     Cherbourg
# 2            3         1       3  ...  26.0   7.9250  Southhampton
# 3            4         1       1  ...  35.0  53.1000  Southhampton
# 4            5         0       3  ...  35.0   8.0500  Southhampton
#
# [5 rows x 8 columns]

# %%
# Name, Age, Pclass 열만 조회
titanic.loc[:, ['Name', 'Age', 'Pclass']]
# Out:
#                                                   Name   Age  Pclass
# 0                              Braund, Mr. Owen Harris  22.0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0       1
# 2                               Heikkinen, Miss. Laina  26.0       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0       1
# 4                             Allen, Mr. William Henry  35.0       3
# ..                                                 ...   ...     ...
# 886                              Montvila, Rev. Juozas  27.0       2
# 887                       Graham, Miss. Margaret Edith  19.0       1
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN       3
# 889                              Behr, Mr. Karl Howell  26.0       1
# 890                                Dooley, Mr. Patrick  32.0       3
#
# [891 rows x 3 columns]

# %%
# Name, Age, Pclass 열만 Name으로 오름차순 정렬해서 조회
titanic[['Name', 'Age', 'Pclass']].sort_values('Name', ascending=True)
# Out:
#                                       Name   Age  Pclass
# 845                    Abbing, Mr. Anthony  42.0       3
# 746            Abbott, Mr. Rossmore Edward  16.0       3
# 279       Abbott, Mrs. Stanton (Rosa Hunt)  35.0       3
# 308                    Abelson, Mr. Samuel  30.0       2
# 874  Abelson, Mrs. Samuel (Hannah Wizosky)  28.0       2
# ..                                     ...   ...     ...
# 286                de Mulder, Mr. Theodore  30.0       3
# 282              de Pelsmaeker, Mr. Alfons  16.0       3
# 361              del Carlo, Mr. Sebastiano  29.0       2
# 153        van Billiard, Mr. Austin Blyler  40.5       3
# 868            van Melkebeke, Mr. Philemon   NaN       3
#
# [891 rows x 3 columns]

# %%
# Survived, Pclass, Sex, Age 열만 갖는 titanic_test 데이터프레임 만들기
titanic_test = titanic[['Survived', 'Pclass', 'Sex', 'Age']].copy()
titanic_test.head()
# Out:
#    Survived  Pclass     Sex   Age
# 0         0       3    male  22.0
# 1         1       1  female  38.0
# 2         1       3  female  26.0
# 3         1       1  female  35.0
# 4         0       3    male  35.0

# %% [markdown]
# **2) 행 조회**
#
#
# - **df.loc[[행이름]:,]** 형태로 조회하면 특정 행을 조회합니다.
# - **df.loc[[행이름]]** 형태로 **열 부분을 생략**할 수 있습니다.

# %%
# 데이터프레임 확인
stock.head()
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# 2000-01-03  4.017857  3.631696  3.745536  3.997768  133949200   3.470226
# 2000-01-04  3.950893  3.613839  3.866071  3.660714  128094400   3.177650
# 2000-01-05  3.948661  3.678571  3.705357  3.714286  194580400   3.224152
# 2000-01-06  3.821429  3.392857  3.790179  3.392857  191993200   2.945139
# 2000-01-07  3.607143  3.410714  3.446429  3.553571  115183600   3.084645

# %%
# Date가 '2015-01-02'인 행 조회 --> 데이터프레임
stock.loc[['2015-01-02'], :]
# Out:
#                   High         Low  ...    Volume   Adj Close
# 2015-01-02  111.440002  107.349999  ...  53204600  100.216454
#
# [1 rows x 6 columns]

# %%
# Date가 '2015-01-02', '2015-01-06', '2015-01-08'인 행 조회
stock.loc[['2015-01-02', '2015-01-06', '2015-01-08'], :]
# Out:
#                   High         Low  ...    Volume   Adj Close
# 2015-01-02  111.440002  107.349999  ...  53204600  100.216454
# 2015-01-06  107.430000  104.629997  ...  65797100   97.402374
# 2015-01-08  112.150001  108.699997  ...  59364500  102.563072
#
# [3 rows x 6 columns]

# %% [markdown]
# - 범위 조회(마지막 값도 포함됨)

# %%
# Date가 '2015-01-02' ~ '2015-01-08'인 행 조회
stock.loc['2015-01-02':'2015-01-08', :]
# Out:
#                   High         Low  ...    Volume   Adj Close
# 2015-01-02  111.440002  107.349999  ...  53204600  100.216454
# 2015-01-05  108.650001  105.410004  ...  64285500   97.393181
# 2015-01-06  107.430000  104.629997  ...  65797100   97.402374
# 2015-01-07  108.199997  106.699997  ...  40105900   98.768150
# 2015-01-08  112.150001  108.699997  ...  59364500  102.563072
#
# [5 rows x 6 columns]

# %%
# Date가 '2015-01-02', '2015-01-06', '2015-01-08'인 행 조회
stock.loc[['2015-01-02', '2015-01-06', '2015-01-08']]
# Out:
#                   High         Low  ...    Volume   Adj Close
# 2015-01-02  111.440002  107.349999  ...  53204600  100.216454
# 2015-01-06  107.430000  104.629997  ...  65797100   97.402374
# 2015-01-08  112.150001  108.699997  ...  59364500  102.563072
#
# [3 rows x 6 columns]

# %% [markdown]
# - 범위 조회(마지막 값도 포함됨)

# %%
# Date가 '2015-01-02' ~ '2015-01-08'인 행 조회
stock.loc['2015-01-02':'2015-01-08']
# Out:
#                   High         Low  ...    Volume   Adj Close
# 2015-01-02  111.440002  107.349999  ...  53204600  100.216454
# 2015-01-05  108.650001  105.410004  ...  64285500   97.393181
# 2015-01-06  107.430000  104.629997  ...  65797100   97.402374
# 2015-01-07  108.199997  106.699997  ...  40105900   98.768150
# 2015-01-08  112.150001  108.699997  ...  59364500  102.563072
#
# [5 rows x 6 columns]

# %% [markdown]
# **3) 행, 열 조회**
#
# - **df.loc[[행이름]:[열이름]]** 형태로 조회하면 특정 행의  특정 열을 조회합니다.

# %%
# Date가 '2015-01-02'인 행의 Close 열
stock.loc[['2015-01-02'], ['Close']]
# Out:
#                  Close
# 2015-01-02  109.330002

# %%
# Date가 '2015-01-02' ~ '2015-01-08' 인 행의 Open ~ Close 열
stock.loc['2015-01-02':'2015-01-08', 'Open':'Close']
# Out:
#                   Open       Close
# 2015-01-02  111.389999  109.330002
# 2015-01-05  108.290001  106.250000
# 2015-01-06  106.540001  106.260002
# 2015-01-07  107.199997  107.750000
# 2015-01-08  109.230003  111.889999

# %%
# Date가 2015-01-02' ~ '2015-01-08'인 행의 Open, Close, Volume 열
stock.loc['2015-01-02':'2015-01-08', ['Open', 'Close', 'Volume']]
# Out:
#                   Open       Close    Volume
# 2015-01-02  111.389999  109.330002  53204600
# 2015-01-05  108.290001  106.250000  64285500
# 2015-01-06  106.540001  106.260002  65797100
# 2015-01-07  107.199997  107.750000  40105900
# 2015-01-08  109.230003  111.889999  59364500

# %%
# Date가 '2015-01-02','2015-01-08'인 행의 Open, Close, Volume 열 
stock.loc[['2015-01-02','2015-01-08'], ['Open', 'Close', 'Volume']]
# Out:
#                   Open       Close    Volume
# 2015-01-02  111.389999  109.330002  53204600
# 2015-01-08  109.230003  111.889999  59364500

# %%
# Date가 '2019-01-01' 부터 모든 행의 Open, Close, Volume 열 
stock.loc['2019-01-01':, ['Open', 'Close', 'Volume']]
# Out:
#                   Open       Close    Volume
# 2019-01-02  154.889999  157.919998  37039700
# 2019-01-03  143.979996  142.190002  91312200
# 2019-01-04  144.529999  148.259995  58607100
# 2019-01-07  148.699997  147.929993  54777800
# 2019-01-08  149.559998  150.750000  41025300
# ...                ...         ...       ...
# 2019-12-24  284.690002  284.269989  12119700
# 2019-12-26  284.820007  289.910004  23280300
# 2019-12-27  291.119995  289.799988  36566500
# 2019-12-30  289.459992  291.519989  36028600
# 2019-12-31  289.929993  293.649994  25201400
#
# [252 rows x 3 columns]

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# stock 데이터프레임에 대해 행을 조회하는 아래 셀 내용욜 수정하거나 작성해 보세요.

# %%
# 2018년 데이터 만 조회(수정 필요)
stock.loc['2018-01-01':'2018-12-31']
# Out:
#                   High         Low  ...    Volume   Adj Close
# 2018-01-02  172.300003  169.259995  ...  25555900  166.804016
# 2018-01-03  174.550003  171.960007  ...  29517900  166.774963
# 2018-01-04  173.470001  172.080002  ...  22434600  167.549622
# 2018-01-05  175.369995  173.050003  ...  23660000  169.457214
# 2018-01-08  175.610001  173.929993  ...  20567800  168.827820
# ...                ...         ...  ...       ...         ...
# 2018-12-24  151.550003  146.589996  ...  37169200  144.314041
# 2018-12-26  157.229996  146.720001  ...  58582500  154.476852
# 2018-12-27  156.770004  150.070007  ...  53117100  153.474335
# 2018-12-28  158.520004  154.550003  ...  42291400  153.552978
# 2018-12-31  159.360001  156.479996  ...  35003500  155.037109
#
# [251 rows x 6 columns]

# %%
stock[stock.index.str.contains('2018')]
# Out:
#                   High         Low  ...    Volume   Adj Close
# 2018-01-02  172.300003  169.259995  ...  25555900  166.804016
# 2018-01-03  174.550003  171.960007  ...  29517900  166.774963
# 2018-01-04  173.470001  172.080002  ...  22434600  167.549622
# 2018-01-05  175.369995  173.050003  ...  23660000  169.457214
# 2018-01-08  175.610001  173.929993  ...  20567800  168.827820
# ...                ...         ...  ...       ...         ...
# 2018-12-24  151.550003  146.589996  ...  37169200  144.314041
# 2018-12-26  157.229996  146.720001  ...  58582500  154.476852
# 2018-12-27  156.770004  150.070007  ...  53117100  153.474335
# 2018-12-28  158.520004  154.550003  ...  42291400  153.552978
# 2018-12-31  159.360001  156.479996  ...  35003500  155.037109
#
# [251 rows x 6 columns]

# %%
stock.filter(like='2018', axis=0)
# Out:
#                   High         Low  ...    Volume   Adj Close
# 2018-01-02  172.300003  169.259995  ...  25555900  166.804016
# 2018-01-03  174.550003  171.960007  ...  29517900  166.774963
# 2018-01-04  173.470001  172.080002  ...  22434600  167.549622
# 2018-01-05  175.369995  173.050003  ...  23660000  169.457214
# 2018-01-08  175.610001  173.929993  ...  20567800  168.827820
# ...                ...         ...  ...       ...         ...
# 2018-12-24  151.550003  146.589996  ...  37169200  144.314041
# 2018-12-26  157.229996  146.720001  ...  58582500  154.476852
# 2018-12-27  156.770004  150.070007  ...  53117100  153.474335
# 2018-12-28  158.520004  154.550003  ...  42291400  153.552978
# 2018-12-31  159.360001  156.479996  ...  35003500  155.037109
#
# [251 rows x 6 columns]

# %%
# 2019년 데이터만 갖는 stock_2019 데이터프레임 만들기
stock_2019 = stock.loc['2019-01-01':'2019-12-31'].copy()
stock_2019.head()
# Out:
#                   High         Low  ...    Volume   Adj Close
# 2019-01-02  158.850006  154.229996  ...  37039700  155.214004
# 2019-01-03  145.720001  142.000000  ...  91312200  139.753540
# 2019-01-04  148.550003  143.800003  ...  58607100  145.719513
# 2019-01-07  148.830002  145.899994  ...  54777800  145.395203
# 2019-01-08  151.820007  148.520004  ...  41025300  148.166870
#
# [5 rows x 6 columns]

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# 2019년 12월 High, Low, Open, Close 데이터만 갖는 **stock_201912** 데이터프레임을 만들어 보세요.

# %%
# stock_201912 만들기
stock_201912 = stock.loc['2019-12-01':'2019-12-31', ['Low', 'Open', 'Close']].copy()

# 확인
stock_201912.head()
# Out:
#                    Low        Open       Close
# 2019-12-02  263.450012  267.269989  264.160004
# 2019-12-03  256.290008  258.309998  259.450012
# 2019-12-04  260.679993  261.070007  261.739990
# 2019-12-05  262.730011  263.790008  265.579987
# 2019-12-06  267.299988  267.480011  270.709992

# %%
# stock_201912 데이터프레임을 만든 후 다음 코드를 실행해 보세요.
stock_201912.plot()

# %% [markdown]
# ## 4.3. 위치로 조회
#
# - **df.iloc[[행번호],[열번호]]** 형태로 사용해 조회할 수 있습니다.
# - 행 번호, 열 번호를 지정하는 차이 외에는 .loc[]와 사용 방법이 같습니다.

# %%
# 데이터프레임 확인
stock.head()
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# 2000-01-03  4.017857  3.631696  3.745536  3.997768  133949200   3.470226
# 2000-01-04  3.950893  3.613839  3.866071  3.660714  128094400   3.177650
# 2000-01-05  3.948661  3.678571  3.705357  3.714286  194580400   3.224152
# 2000-01-06  3.821429  3.392857  3.790179  3.392857  191993200   2.945139
# 2000-01-07  3.607143  3.410714  3.446429  3.553571  115183600   3.084645

# %%
# 첫 번째 행 조회 --> 시리즈
stock.iloc[0]
# Out:
# High         4.017857e+00
# Low          3.631696e+00
# Open         3.745536e+00
# Close        3.997768e+00
# Volume       1.339492e+08
# Adj Close    3.470226e+00
# Name: 2000-01-03, dtype: float64

# %%
# 두 번째 행 조회 --> 시리즈
stock.iloc[1]
# Out:
# High         3.950893e+00
# Low          3.613839e+00
# Open         3.866071e+00
# Close        3.660714e+00
# Volume       1.280944e+08
# Adj Close    3.177650e+00
# Name: 2000-01-04, dtype: float64

# %%
# 두 번째 행 조회
stock.iloc[[1]]
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# 2000-01-04  3.950893  3.613839  3.866071  3.660714  128094400    3.17765

# %%
# 두 번째 열 조회
stock.iloc[:, [1]]
# Out:
#                    Low
# 2000-01-03    3.631696
# 2000-01-04    3.613839
# 2000-01-05    3.678571
# 2000-01-06    3.392857
# 2000-01-07    3.410714
# ...                ...
# 2019-12-24  282.920013
# 2019-12-26  284.700012
# 2019-12-27  288.119995
# 2019-12-30  285.220001
# 2019-12-31  289.519989
#
# [5031 rows x 1 columns]

# %%
# 첫 번쨰, 세 번쨰, 다섯 번째 행 조회
stock.iloc[[0, 2, 4]]
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# 2000-01-03  4.017857  3.631696  3.745536  3.997768  133949200   3.470226
# 2000-01-05  3.948661  3.678571  3.705357  3.714286  194580400   3.224152
# 2000-01-07  3.607143  3.410714  3.446429  3.553571  115183600   3.084645

# %%
# 첫 번째 ~ 세 번째 행 조회
stock.iloc[0:3]
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# 2000-01-03  4.017857  3.631696  3.745536  3.997768  133949200   3.470226
# 2000-01-04  3.950893  3.613839  3.866071  3.660714  128094400   3.177650
# 2000-01-05  3.948661  3.678571  3.705357  3.714286  194580400   3.224152

# %%
# 첫 번째 ~ 세 번째 열 조회
stock.iloc[:, 0:3]
# Out:
#                   High         Low        Open
# 2000-01-03    4.017857    3.631696    3.745536
# 2000-01-04    3.950893    3.613839    3.866071
# 2000-01-05    3.948661    3.678571    3.705357
# 2000-01-06    3.821429    3.392857    3.790179
# 2000-01-07    3.607143    3.410714    3.446429
# ...                ...         ...         ...
# 2019-12-24  284.890015  282.920013  284.690002
# 2019-12-26  289.980011  284.700012  284.820007
# 2019-12-27  293.970001  288.119995  291.119995
# 2019-12-30  292.690002  285.220001  289.459992
# 2019-12-31  293.679993  289.519989  289.929993
#
# [5031 rows x 3 columns]

# %%
# 참고: 3의 배수인 행 조회
stock.iloc[::3]
# Out:
#                   High         Low  ...     Volume   Adj Close
# 2000-01-03    4.017857    3.631696  ...  133949200    3.470226
# 2000-01-06    3.821429    3.392857  ...  191993200    2.945139
# 2000-01-11    3.549107    3.232143  ...  110387200    2.875386
# 2000-01-14    3.651786    3.549107  ...   97594000    3.113708
# 2000-01-20    4.339286    4.053571  ...  457783200    3.518665
# ...                ...         ...  ...        ...         ...
# 2019-12-10  270.070007  265.859985  ...   22605100  267.844330
# 2019-12-13  275.299988  270.929993  ...   33396900  274.498535
# 2019-12-18  281.899994  279.119995  ...   29007100  279.077667
# 2019-12-23  284.250000  280.369995  ...   24643000  283.327576
# 2019-12-27  293.970001  288.119995  ...   36566500  289.113831
#
# [1677 rows x 6 columns]

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# 다음 셀들을 실행하면서 그 의미를 확인해 보세요.

# %%
stock.iloc[1, 1]

# %%
stock.iloc[1, -1]

# %%
stock.iloc[0:4, 0:3]

# %%
stock.iloc[0:4, [0, 2, 4]]

# %%
stock.iloc[::3, [0, 2, 4]]

# %%
stock.iloc[-5:-1]

# %% [markdown]
# ## 4.4. 조건으로 조회
#
# - **df.loc[조건]** 형태로 조건을 지정해 조건에 만족하는 데이터만 조회할 수 있습니다.
# - 우선 조건이 제대로 판단이 되는지 확인한 후 그 **조건을 대 괄호 안에** 넣으면 됩니다.

# %%
# graduate 데이터 불러오기
file_path = 'https://raw.githubusercontent.com/Jangrae/csv/master/Graduate_apply.csv'
graduate = pd.read_csv(file_path, sep = ',', skipinitialspace = True)  
graduate.head()
# Out:
#    admit  gre   gpa  rank
# 0      0  380  3.61     3
# 1      1  660  3.67     3
# 2      1  800  4.00     1
# 3      1  640  3.19     4
# 4      0  520  2.93     4

# %%
# 데이터프레임 확인
graduate.head()
# Out:
#    admit  gre   gpa  rank
# 0      0  380  3.61     3
# 1      1  660  3.67     3
# 2      1  800  4.00     1
# 3      1  640  3.19     4
# 4      0  520  2.93     4

# %% [markdown]
# **1) 조건 확인**

# %%
# 조건을 비교한 결과(True/False) 값으로 반환됨
graduate['gpa'] > 3.5
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 395     True
# 396    False
# 397    False
# 398     True
# 399     True
# Name: gpa, Length: 400, dtype: bool

# %% [markdown]
# **2) 단일 조건을 반족하는 행 조회**

# %%
# 조건을 비교한 결과 True 인 값 조회
graduate.loc[graduate['gpa'] > 3.5].head()
# Out:
#     admit  gre   gpa  rank
# 0       0  380  3.61     3
# 1       1  660  3.67     3
# 2       1  800  4.00     1
# 9       0  700  3.92     2
# 10      0  800  4.00     4

# %%
# rank == 1 조건을 비교한 결과 True 인 값 조회
graduate.loc[graduate['rank'] == 1].head()
# Out:
#     admit  gre   gpa  rank
# 2       1  800  4.00     1
# 6       1  560  2.98     1
# 11      0  440  3.22     1
# 12      1  760  4.00     1
# 14      1  700  4.00     1

# %% [markdown]
# **3) 여러 조건을 만족하는 행 조회**
#
# - [ ]안에 조건을 여러개 연결할 때 **and와 or 대신에 &와 |**를 사용해야 합니다.
# - 그리고 각 조건들은 **(조건1) & (조건2)** 형태로 괄호로 묶어야 합니다.

# %%
# and 조건으로 여러 조건 함께 조회
graduate.loc[(graduate['gpa'] > 3.0) & (graduate['rank'] == 3)].head()
# Out:
#     admit  gre   gpa  rank
# 0       0  380  3.61     3
# 1       1  660  3.67     3
# 8       1  540  3.39     3
# 15      0  480  3.44     3
# 20      0  500  3.17     3

# %%
# or 조건으로 여러 조건 함께 조회
graduate.loc[(graduate['gpa'] > 3.0) | (graduate['rank'] == 3)].head()
# Out:
#    admit  gre   gpa  rank
# 0      0  380  3.61     3
# 1      1  660  3.67     3
# 2      1  800  4.00     1
# 3      1  640  3.19     4
# 7      0  400  3.08     2

# %% [markdown]
# **4) 편리한 isin(), between() 메소드**

# %% [markdown]
# - **isin([값1, 값2, 값3])**: 값1 또는 값2 또는 값3인 데이터만 조회합니다.

# %%
# 여러 값을 한꺼번에 나열해서 비교
graduate.loc[graduate['rank'].isin([1, 2])].head()
# Out:
#    admit  gre   gpa  rank
# 2      1  800  4.00     1
# 5      1  760  3.00     2
# 6      1  560  2.98     1
# 7      0  400  3.08     2
# 9      0  700  3.92     2

# %%
# 위 문장을 분리하면
graduate.loc[(graduate['rank'] == 1) | (graduate['rank'] == 2)].head()
# Out:
#    admit  gre   gpa  rank
# 2      1  800  4.00     1
# 5      1  760  3.00     2
# 6      1  560  2.98     1
# 7      0  400  3.08     2
# 9      0  700  3.92     2

# %% [markdown]
# - **between(값1, 값2)**: 값1 ~ 값2까지 범위안의 데이터만 조회합니다.

# %%
# 어디부터 어디까지 범위를 한 번에 지정
graduate.loc[graduate['rank'].between(1, 3)].head()
# Out:
#    admit  gre   gpa  rank
# 0      0  380  3.61     3
# 1      1  660  3.67     3
# 2      1  800  4.00     1
# 5      1  760  3.00     2
# 6      1  560  2.98     1

# %%
# 위 문장을 분리하면
graduate.loc[(graduate['rank'] >= 1) & (graduate['rank'] <= 3)].head()
# Out:
#    admit  gre   gpa  rank
# 0      0  380  3.61     3
# 1      1  660  3.67     3
# 2      1  800  4.00     1
# 5      1  760  3.00     2
# 6      1  560  2.98     1

# %%
# 어디부터 어디까지 범위를 한 번에 지정
graduate.loc[graduate['gre'].between(700, 800)].head()
# Out:
#     admit  gre   gpa  rank
# 2       1  800  4.00     1
# 5       1  760  3.00     2
# 9       0  700  3.92     2
# 10      0  800  4.00     4
# 12      1  760  4.00     1

# %% [markdown]
# **5) 조건을 만족하는 행의 일부 열 조회**
#
# - **df.loc[조건, ['열']]** 형태로 열 하나, 또는 **df.loc[조건, ['열1', '열2']]** 형태로 여러 열을 조회합니다.

# %%
# 조건에 맞는 하나의 열 조회
graduate.loc[graduate['gpa'] > 3.0, ['gre']].head()
# Out:
#    gre
# 0  380
# 1  660
# 2  800
# 3  640
# 7  400

# %%
# 조건에 맞는 여러 열 조회
graduate.loc[graduate['gpa'] > 3.0, ['admit', 'gpa', 'gre']].head()
# Out:
#    admit   gpa  gre
# 0      0  3.61  380
# 1      1  3.67  660
# 2      1  4.00  800
# 3      1  3.19  640
# 7      0  3.08  400

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jangrae/img/master/practice_01.png' width=120 align="left"/>

# %% [markdown]
# Close가 Low와 같은 행의 High, Low, Open, Close만 앞의 5행만 조회해 보세요.

# %%
# Close와 Low가 같은 5개 행 조회

# %% [markdown]
# Close가 가장 큰 High, Low, Open, Close를 조회해 보세요.

# %%
# Close가 가장 큰 행 조회

# %% [markdown]
# **6) 문자열에 있는 특정 문자 검색**
#
# - **contains()** 메소드를 사용해 문자열 포함 여부를 조건으로 지정할 수 있습니다.

# %%
# 데이터프레임 확인
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  ...   Age     Fare      Embarked
# 0            1         0       3  ...  22.0   7.2500  Southhampton
# 1            2         1       1  ...  38.0  71.2833     Cherbourg
# 2            3         1       3  ...  26.0   7.9250  Southhampton
# 3            4         1       1  ...  35.0  53.1000  Southhampton
# 4            5         0       3  ...  35.0   8.0500  Southhampton
#
# [5 rows x 8 columns]

# %%
# 조건문 작성
titanic['Name'].str.contains('May')
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
# 조건을 만족하는 행 찾기
titanic.loc[titanic['Name'].str.contains('May')]
# Out:
#      PassengerId  Survived  Pclass  ...   Age     Fare      Embarked
# 3              4         1       1  ...  35.0  53.1000  Southhampton
# 256          257         1       1  ...   NaN  79.2000     Cherbourg
# 530          531         1       2  ...   2.0  26.0000  Southhampton
# 710          711         1       1  ...  24.0  49.5042     Cherbourg
#
# [4 rows x 8 columns]

# %%
titanic.loc[titanic['Name'].str.contains('Dawson')]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, Fare, Embarked]
# Index: []

# %% [markdown]
# ## 4.5. 기본 집계

# %% [markdown]
# ### 4.5.1. 고유값 확인
#
# - 범주형 열(열이 가진 값이 일정한 값인 경우, 성별, 등급 등)인지 확인하는 대표적인 방법입니다.

# %%
# Embarked 열 고유값 확인
titanic['Embarked'].unique()
# Out:
# array(['Southhampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
titanic['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
# Embarked 열 고유값 개수 확인, NaN 값 제외
titanic['Embarked'].value_counts()
# Out:
# Southhampton    644
# Cherbourg       168
# Queenstown       77
# Name: Embarked, dtype: int64

# %%
titanic['Embarked'].value_counts().plot(kind='bar')

# %%
# Embarked 열 고유값 개수 확인, NaN값 포함
titanic['Embarked'].value_counts(dropna=False)
# Out:
# Southhampton    644
# Cherbourg       168
# Queenstown       77
# NaN               2
# Name: Embarked, dtype: int64

# %%
# Pclass 열 고유값 개수 확인
titanic['Pclass'].value_counts(dropna=False)
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# ### 4.5.2. 기본 통계 함수 사용
#
# - 데이터를 1차 집계 한 후 분석을 진행하는 경우가 많으므로 필히 알라두어야 할 내용입니다.
# - 이후에 배우는 Groupby 기능에서 같이 사용됩니다.

# %% [markdown]
# **1) 합, 평균값**

# %%
# 모든 열 합계 조회
titanic.sum()
# Out:
# PassengerId                                               397386
# Survived                                                     342
# Pclass                                                      2057
# Name           Braund, Mr. Owen HarrisCumings, Mrs. John Brad...
# Sex            malefemalefemalefemalemalemalemalemalefemalefe...
# Age                                                      21205.2
# Fare                                                     28693.9
# dtype: object

# %%
# 모든 열 평균값 조회
titanic.mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# Fare            32.204208
# dtype: float64

# %%
# Fare 열 합계 조회
titanic['Fare'].sum()
# Out:
# 28693.9493

# %%
# 난 안쓸래!
titanic.Fare.sum()
# Out:
# 28693.9493

# %%
# Age, Fare 열 평균값 확인
titanic[['Age', 'Fare']].mean()
# Out:
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %% [markdown]
# **2) 최댓값, 최솟값**

# %%
# 모든 열 최댓값 조회
titanic.max()
# Out:
# PassengerId                            891
# Survived                                 1
# Pclass                                   3
# Name           van Melkebeke, Mr. Philemon
# Sex                                   male
# Age                                     80
# Fare                               512.329
# dtype: object

# %%
# 모든 행 최솟값 조회
titanic.min()
# Out:
# PassengerId                      1
# Survived                         0
# Pclass                           1
# Name           Abbing, Mr. Anthony
# Sex                         female
# Age                           0.42
# Fare                             0
# dtype: object

# %%
# Fare 열 최댓값 조회
titanic['Fare'].max()
# Out:
# 512.3292

# %%
# Age, Fare 열 최솟값 조회
titanic[['Age', 'Fare']].min()
# Out:
# Age     0.42
# Fare    0.00
# dtype: float64

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age        Fare
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118   32.204208
# std     257.353842    0.486592    0.836071   14.526497   49.693429
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    7.910400
# 50%     446.000000    0.000000    3.000000   28.000000   14.454200
# 75%     668.500000    1.000000    3.000000   38.000000   31.000000
# max     891.000000    1.000000    3.000000   80.000000  512.329200

# %% [markdown]
# ## <center>수고하셨습니다.</center>
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/end.png' width=200/></center>
