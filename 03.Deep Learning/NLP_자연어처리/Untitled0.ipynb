# %%
import sys
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
# original_stdout = sys.stdout
# file = open('file_20200529.txt', 'w', encoding='UTF-8')
# sys.stdout = file

# %%
url = urlopen('https://www.yna.co.kr/view/AKR20200528175700530?section=safe/news&site=topnews01')
soup = BeautifulSoup(url, 'lxml')

# %%
title = soup.find_all("div", {"id":"container"})
title2 = title.find_all("h1")
contents = soup.find_all("div", {"id":"story-wrap article"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-4b394e4becda> in <module>()
#       1 title = soup.find_all("div", {"id":"container"})
# ----> 2 title2 = title.find_all("h1")
#       3 contents = soup.find_all("div", {"id":"story-wrap article"})
#
# /usr/local/lib/python3.6/dist-packages/bs4/element.py in __getattr__(self, key)
#    1882     def __getattr__(self, key):
#    1883         raise AttributeError(
# -> 1884             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1885         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
print(title)
# Out:
# [<div class="container" id="container">
# <div class="contents">
# <header class="title-article01">
# <div class="nav-path01">
# <span class="home"><a href="//www.yna.co.kr/safe/index">홈</a></span>
# <span class="line">|</span>
# <span class="current"><a href="//www.yna.co.kr/safe/news">최신기사</a></span>
# </div>
# <h1 class="tit" data-cid="수도권 코로나19 급속 확산 비상…앞으로 2주가 '고비'">수도권 코로나19 급속 확산 비상…앞으로 2주가 '고비'</h1>
# <p class="update-time"><span class="hidden-obj">송고시간</span>2020-05-29 06:00
# </p>
# </header>
# <div class="content01">
# <div class="option-zone">
# <div>
# <div class="share-type01 share-script">
# <span class="hidden-obj">sns 공유</span>
# <button class="kkt" type="button"><span>카카오톡</span></button>
# <button class="fb" type="button"><span>페이스북</span></button>
# <button class="tw" type="button"><span>트위터</span></button>
# <button class="kks" type="button"><span>카카오스토리</span></button>
# <button class="band" type="button"><span>밴드</span></button>
# ...

# %%
print(contents)
# Out:
# []
