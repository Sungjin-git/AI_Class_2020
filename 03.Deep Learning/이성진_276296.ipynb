# %% [markdown]
# - 이름: 이성진
# - 사번: 276296
# - 이름_사번.ipynb 파일 형식으로 올려주세요.  예)홍길동_111111.ipynb

# %% [markdown]
# # Tensorflow & Keras를 활용한 딥러닝 (과정평가)

# %% [markdown]
# **1번 문제**
#
# ######Keras로 다계층신경망(Dense함수사용)을 구현하십시요.
#
# ######데이터: cifar10 (힌트: 이 경우에는 3채널이기 때문에 데이터의 벡터사이즈가 32* 32* 3이 되어야 합니다)
#
# ######히든레이어1) 유닛개수: 1000개
#
# ######히든레이어2) 유닛개수: 1000개
#
# ######히든레이어3) 유닛개수: 1000개
#
# ######참고) 정확도는 낮아도 됩니다. 구현한 코드만 볼 것입니다.

# %%
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense

# Data
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
print(train_images.shape, train_labels.shape)
print(test_images.shape, test_labels.shape)

train_images = train_images.reshape(train_images.shape[0], 32*32*3).astype('float32') / 255.0
test_images = test_images.reshape(test_images.shape[0], 32*32*3).astype('float32') / 255.0
train_labels = np_utils.to_categorical(train_labels)
test_labels = np_utils.to_categorical(test_labels)

# Model, Cost, Train
model = Sequential()
model.add(Dense(1000, activation='relu'))
model.add(Dense(1000, activation='relu'))
model.add(Dense(1000, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Training
model.fit(train_images, train_labels, epochs=5, batch_size=128, verbose=1)
model.summary()

# Test
_, acc = model.evaluate(test_images, test_labels)
print('Accuracy: ', acc)
# Out:
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)
# Epoch 1/5
# 50000/50000 [==============================] - 44s 882us/step - loss: 1.8612 - accuracy: 0.3268
# Epoch 2/5
# 50000/50000 [==============================] - 41s 815us/step - loss: 1.6524 - accuracy: 0.4048
# Epoch 3/5
# 50000/50000 [==============================] - 41s 818us/step - loss: 1.5686 - accuracy: 0.4372
# Epoch 4/5
# 50000/50000 [==============================] - 41s 819us/step - loss: 1.5012 - accuracy: 0.4614
# Epoch 5/5
# 50000/50000 [==============================] - 41s 817us/step - loss: 1.4505 - accuracy: 0.4799
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_10 (Dense)             (None, 1000)              3073000
# _________________________________________________________________
# dense_11 (Dense)             (None, 1000)              1001000
# ...

# %% [markdown]
# **2번 문제**
#
# ###### Keras로 CNN을 구현하십시요.
# ###### 데이터: Cifar10
# ###### 첫번째레이어) 컨볼루션(필터개수: 128, 필터사이즈: 4-by-4, 스트라이드: 1)
# ###### 두번째레이어) max풀링
# ###### 세번째레이어) 컨볼루션(필터개수: 128, 필터사이즈: 4-by-4, 스트라이드: 1)
# ###### 네번째레이어) max풀링
# ###### 다섯번째레이어) Flatten
# ###### 여섯번째레이어) Softmax
# ###### 참고) 정확도는 낮아도 됩니다. 구현한 코드만 볼 것입니다.

# %%
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, pooling, Flatten, Dense

# Data
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
print(train_images.shape, train_labels.shape)
print(test_images.shape, test_labels.shape)

train_images = train_images.reshape(train_images.shape[0], 32, 32, 3).astype('float32') / 255.0
test_images = test_images.reshape(test_images.shape[0], 32, 32, 3).astype('float32') / 255.0
train_labels = np_utils.to_categorical(train_labels)
test_labels = np_utils.to_categorical(test_labels)

# Model, Cost, Train
model = Sequential()
model.add(Conv2D(128, (4,4), padding='same', strides=(1,1), activation='relu', input_shape=(32,32,3)))
model.add(pooling.MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(128, (4,4), padding='same', strides=(1,1), activation='relu'))
model.add(pooling.MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(10, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Training
model.fit(train_images, train_labels, epochs=2, batch_size=128, verbose=1)
model.summary()

# Test
_, acc = model.evaluate(test_images, test_labels)
print('Accuracy: ', acc)
# Out:
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)
# Epoch 1/2
# 50000/50000 [==============================] - 541s 11ms/step - loss: 1.4985 - accuracy: 0.4669
# Epoch 2/2
# 50000/50000 [==============================] - 541s 11ms/step - loss: 1.0939 - accuracy: 0.6193
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 32, 32, 128)       6272
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 128)       262272
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# ...
